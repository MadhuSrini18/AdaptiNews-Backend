# %% [markdown]
# # Load the data

# %%
import pandas as pd

data = pd.read_json('data/bloomberg_quint_news.json')
data
# Out:
#                                                     url  \
# 0     https://www.bloombergquint.com/markets/all-you...
# 1     https://www.bloombergquint.com/business/bridge...
# 2     https://www.bloombergquint.com/markets/stocks-...
# 3     https://www.bloombergquint.com/research-report...
# 4     https://www.bloombergquint.com/business/cp-rai...
# ...                                                 ...
# 7013  https://www.bloombergquint.com/videos/2016/04/...
# 7014  https://www.bloombergquint.com/videos/2016/04/...
# 7015  https://www.bloombergquint.com/videos/2016/04/...
# 7016  https://www.bloombergquint.com/videos/2016/04/...
# 7017  https://www.bloombergquint.com/videos/2016/04/...
#
#                                                   title  \
# 0     All You Need To Know Going Into Trade On Septe...
# 1     Bridgestone CEO Backs Safe Tokyo Olympics, Dia...
# 2     Stocks To Watch: HCL Tech, Cyient, M&M Financi...
# 3     Localised Lockdowns Cannot But Impinge On Econ...
# ...

# %% [markdown]
# # Delete missing values

# %%
def check_missing_values(df):
    # Check for NaN, missing, or NaT values
    missing_rows = df[df.isnull().any(axis=1)]

    if not missing_rows.empty:
        print("Deleting rows with missing values...")
        df.dropna(inplace=True)
        print("Rows with missing values have been deleted.")
    else:
        print("There are no missing values in the DataFrame.")

# Example usage:
check_missing_values(data)
data
# Out:
# Deleting rows with missing values...
# Rows with missing values have been deleted.
#                                                     url  \
# 0     https://www.bloombergquint.com/markets/all-you...
# 1     https://www.bloombergquint.com/business/bridge...
# 2     https://www.bloombergquint.com/markets/stocks-...
# 3     https://www.bloombergquint.com/research-report...
# 4     https://www.bloombergquint.com/business/cp-rai...
# ...                                                 ...
# 5985  https://www.bloombergquint.com/opinion/2015/10...
# 6286  https://www.bloombergquint.com/opinion/2015/12...
# 6433  https://www.bloombergquint.com/opinion/2015/12...
# 6513  https://www.bloombergquint.com/politics/2016/0...
# 6660  https://www.bloombergquint.com/technology/2016...
#
#                                                   title  \
# 0     All You Need To Know Going Into Trade On Septe...
# 1     Bridgestone CEO Backs Safe Tokyo Olympics, Dia...
# ...

# %% [markdown]
# # Text pre-processing

# %%
import re
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer

def _removeNonAscii(s):
    return "".join(i for i in s if  ord(i)<128)

def make_lower_case(text):
    return text.lower()

def remove_stop_words(text):
    text = text.split()
    stops = set(stopwords.words("english"))
    text = [w for w in text if not w in stops]
    text = " ".join(text)
    return text

def remove_html(text):
    html_pattern = re.compile('<.*?>')
    return html_pattern.sub(r'', text)

def remove_punctuation(text):
    tokenizer = RegexpTokenizer(r'\w+')
    text = tokenizer.tokenize(text)
    text = " ".join(text)
    return text

# call the functions and clean the text for the title, short_description, and description columns
data['title'] = data['title'].apply(_removeNonAscii)
data['title'] = data['title'].apply(make_lower_case)
data['title'] = data['title'].apply(remove_stop_words)
data['title'] = data['title'].apply(remove_punctuation)
data['title'] = data['title'].apply(remove_html)

data['short_description'] = data['short_description'].apply(_removeNonAscii)
data['short_description'] = data['short_description'].apply(make_lower_case)
data['short_description'] = data['short_description'].apply(remove_stop_words)
data['short_description'] = data['short_description'].apply(remove_punctuation)
data['short_description'] = data['short_description'].apply(remove_html)

data['description'] = data['description'].apply(_removeNonAscii)
data['description'] = data['description'].apply(make_lower_case)
data['description'] = data['description'].apply(remove_stop_words)
data['description'] = data['description'].apply(remove_punctuation)
data['description'] = data['description'].apply(remove_html)

data
# Out:
#                                                     url  \
# 0     https://www.bloombergquint.com/markets/all-you...
# 1     https://www.bloombergquint.com/business/bridge...
# 2     https://www.bloombergquint.com/markets/stocks-...
# 3     https://www.bloombergquint.com/research-report...
# 4     https://www.bloombergquint.com/business/cp-rai...
# ...                                                 ...
# 5985  https://www.bloombergquint.com/opinion/2015/10...
# 6286  https://www.bloombergquint.com/opinion/2015/12...
# 6433  https://www.bloombergquint.com/opinion/2015/12...
# 6513  https://www.bloombergquint.com/politics/2016/0...
# 6660  https://www.bloombergquint.com/technology/2016...
#
#                                                   title  \
# 0                    need know going trade september 23
# 1     bridgestone ceo backs safe tokyo olympics dial...
# 2     stocks watch hcl tech cyient m m financial ser...
# 3     localised lockdowns cannot impinge economic ac...
# ...

# %%
corpus_title = data['title'].tolist()
corpus_short_description = data['short_description'].tolist()
corpus_description = data['description'].tolist()

def get_corpus(text):
    words = []
    for i in text:
        text = [word for word in i.split()]
        words.append(text)
    return words

corpus_title = get_corpus(corpus_title)
corpus_short_description = get_corpus(corpus_short_description)
corpus_description = get_corpus(corpus_description)

# %% [markdown]
# # Load the corpus

# %%
from gensim.models import KeyedVectors

glove_model = KeyedVectors.load_word2vec_format('gloves/converted_vectors300.txt', binary=False)

# %% [markdown]
# # Search based on the keywords

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import string
import numpy as np

def get_average_word2vec(tokens_list, vector=glove_model, generate_missing=False, k=300):
    if len(tokens_list) < 1:
        return np.zeros(k)
    
    vectorized = []
    for word in tokens_list:
        if word in vector:
            vectorized.append(vector[word])
        elif generate_missing:
            vectorized.append(np.random.rand(k))
    
    if not vectorized:
        return np.zeros(k)
    
    # Only compute the mean if there are non-zero vectors
    if len(vectorized) > 0:
        return np.mean(vectorized, axis=0)
    else:
        return np.zeros(k)



def get_word2vec_embeddings(vectors, corpus, generate_missing=False):
    embeddings = []
    for title in corpus:
        averaged_embedding = get_average_word2vec(title, vectors, generate_missing=generate_missing)
        embeddings.append(averaged_embedding)
    return embeddings


from sklearn.metrics.pairwise import cosine_similarity

def recommend_news_based_on_keyword(keyword, vectors, data):
    keyword = keyword.split()
    keyword = get_average_word2vec(keyword, vectors)
    
    # Calculate vectors for title
    # cut down the title into lists of words before applying the get_average_word2vec functio
    data['title_vector'] = data['title'].apply(lambda x: get_average_word2vec(x.split(), vectors))
    data['short_desc_vector'] = data['short_description'].apply(lambda x: get_average_word2vec(x.split(), vectors))
    data['desc_vector'] = data['description'].apply(lambda x: get_average_word2vec(x.split(), vectors))

    # Compute cosine similarity for each title vector
    data['title_similarity'] = data.apply(lambda row: cosine_similarity([row['title_vector']], [keyword])[0][0], axis=1)
    data['short_desc_similarity'] = data.apply(lambda row: cosine_similarity([row['short_desc_vector']], [keyword])[0][0], axis=1)
    data['desc_similarity'] = data.apply(lambda row: cosine_similarity([row['desc_vector']], [keyword])[0][0], axis=1)

    # Combine similarities with weights
    title_weight = 0.7
    short_desc_weight = 0.2
    desc_weight = 0.1

    data['combined_similarity'] = (title_weight * data['title_similarity'] +
                                      short_desc_weight * data['short_desc_similarity'] +
                                      desc_weight * data['desc_similarity'])

    # Sort by title similarity
    data = data.sort_values(by='title_similarity', ascending=False)
    
    return data

recommend_news_based_on_keyword('ukraine', glove_model, data)[:10]
# Out:
#                                                     url  \
# 292   https://www.bloombergquint.com/view/eastern-eu...
# 3566  https://www.bloombergquint.com/politics/russia...
# 3754  https://www.bloombergquint.com/politics/russia...
# 839   https://www.bloombergquint.com/markets/ousted-...
# 1526  https://www.bloombergquint.com/global-economic...
# 1558  https://www.bloombergquint.com/global-economic...
# 2175  https://www.bloombergquint.com/business/ukrain...
# 1999  https://www.bloombergquint.com/onweb/bulgaria-...
# 4000  https://www.bloombergquint.com/politics/ukrain...
# 2645  https://www.bloombergquint.com/business/czech-...
#
#                                                   title  \
# 292              eastern europe feeds shrinking ukraine
# 3566  russia orders army back ukraine border easing ...
# 3754    russia says troop pullback ukraine border begun
# 839   ousted naftogaz boss warns corruption risks uk...
# 1526  blinkens european trip aims bolster ukraine pr...
# ...

# %% [markdown]
# # Search based on author's name

# %%
from sklearn.metrics.pairwise import cosine_similarity

def recommend_news_based_on_author(author, vectors, data, recent=False):
    author = author.split()
    author = get_average_word2vec(author, vectors)
    
    # Calculate vectors for title
    # cut down the title into lists of words before applying the get_average_word2vec functio
    data['author_vector'] = data['author'].apply(lambda x: get_average_word2vec(x.split(), vectors))

    # Compute cosine similarity for each title vector
    data['author_similarity'] = data.apply(lambda row: cosine_similarity([row['author_vector']], [author])[0][0], axis=1)

    # Sort by title similarity
    data = data.sort_values(by='author_similarity', ascending=False)

    # Sort by date_created if recent is True
    if recent:
        data = data.sort_values(by=['author_similarity', 'date_created'], ascending=[False, False])

    
    return data

recommend_news_based_on_author('matthew monks', glove_model, data, recent=True)[:10]
# Out:
#                                                     url  \
# 4018  https://www.bloombergquint.com/onweb/world-s-t...
# 1157  https://www.bloombergquint.com/onweb/tesco-ste...
# 723   https://www.bloombergquint.com/onweb/west-afri...
# 2934  https://www.bloombergquint.com/china/no-respit...
# 1732  https://www.bloombergquint.com/politics/chaoti...
# 1809  https://www.bloombergquint.com/politics/powers...
# 1806  https://www.bloombergquint.com/business/relian...
# 1627  https://www.bloombergquint.com/onweb/singapore...
# 1755  https://www.bloombergquint.com/global-economic...
# 1832  https://www.bloombergquint.com/technology/tikt...
#
#                                                   title  \
# 4018   worlds top cocoa grower says farmer premium stay
# 1157  tesco steps healthy food pledge amid investor ...
# 723   west african cocoa giants report progress defo...
# 2934  respite huarong investors earnings delay adds ...
# 1732  chaotic johnson always struggled rules andu k ...
# ...

# %% [markdown]
# # User preferences

# %%
import json

user = json.load(open('data/user.json'))


user_categories = user['user_categories']
print(user_categories)
# Out:
# {'Nature': {'score': 0.8, 'last_modified': 1711820408.861159}, 'Science': {'score': 1.4400000000000002, 'last_modified': 1711820405.757194}, 'Environment': {'score': 0.8, 'last_modified': 1711820405.020253}, 'Health': {'score': 1.4400000000000002, 'last_modified': 1711820404.893028}, 'Art': {'score': 0.8, 'last_modified': 1711820404.622761}, 'Education': {'score': 0.8, 'last_modified': 1711820403.229797}, 'Self-Help': {'score': 0.8, 'last_modified': 1711820402.950997}, 'History': {'score': 0.8, 'last_modified': 1711820401.579802}, 'Business': {'score': 0, 'last_modified': 1648700000}, 'Opinion/Gadfly': {'score': 0, 'last_modified': 1648700000}}

# %%
def recommend_news_based_on_keyword_and_preferences(keyword, vectors, data, user_preferences=None):
    keyword = keyword.split()
    keyword = get_average_word2vec(keyword, vectors)
    
    # Calculate vectors for title, short description, and description
    data['title_vector'] = data['title'].apply(lambda x: get_average_word2vec(x.split(), vectors))
    data['short_desc_vector'] = data['short_description'].apply(lambda x: get_average_word2vec(x.split(), vectors))
    data['desc_vector'] = data['description'].apply(lambda x: get_average_word2vec(x.split(), vectors))

    # Compute cosine similarity for each feature
    data['title_similarity'] = data.apply(lambda row: cosine_similarity([row['title_vector']], [keyword])[0][0], axis=1)
    data['short_desc_similarity'] = data.apply(lambda row: cosine_similarity([row['short_desc_vector']], [keyword])[0][0], axis=1)
    data['desc_similarity'] = data.apply(lambda row: cosine_similarity([row['desc_vector']], [keyword])[0][0], axis=1)

    # Combine similarities with weights
    title_weight = 0.7
    short_desc_weight = 0.2
    desc_weight = 0.1

    data['combined_similarity'] = (title_weight * data['title_similarity'] +
                                   short_desc_weight * data['short_desc_similarity'] +
                                   desc_weight * data['desc_similarity'])

    # Sort by combined similarity
    data = data.sort_values(by='combined_similarity', ascending=False)
    
    # Prioritize articles based on user preferences for categories
    if user_preferences: # 
        category_weights = user_preferences
        category_max_score = max(category_weights.values(), key=lambda x: x['score'])['score']
        print(category_max_score)
        for category, weight_info in category_weights.items():
            weight = weight_info['score']
            data.loc[data['category'] == category, 'combined_similarity'] *= (weight / category_max_score)

    
    # Sort again by adjusted combined similarity
    data = data.sort_values(by='combined_similarity', ascending=False)
    
    return data

recommend_news_based_on_keyword_and_preferences('google faceboook', glove_model, data, user_categories)[:20]
# Out:
# 1.4400000000000002
#                                                     url  \
# 3003  https://www.bloombergquint.com/quicktakes/how-...
# 2091  https://www.bloombergquint.com/onweb/microsoft...
# 1511  https://www.bloombergquint.com/onweb/vodafone-...
# 1371  https://www.bloombergquint.com/onweb/apple-hir...
# 3196  https://www.bloombergquint.com/politics/facebo...
# 3059  https://www.bloombergquint.com/onweb/facebook-...
# 3878  https://www.bloombergquint.com/politics/google...
# 4123  https://www.bloombergquint.com/law-and-policy/...
# 3550  https://www.bloombergquint.com/technology/appl...
# 3112  https://www.bloombergquint.com/onweb/spotify-u...
# 1092  https://www.bloombergquint.com/onweb/apple-pus...
# 3091  https://www.bloombergquint.com/onweb/apple-set...
# 853   https://www.bloombergquint.com/onweb/microsoft...
# 1860  https://www.bloombergquint.com/technology/appl...
# 3228  https://www.bloombergquint.com/technology/adob...
# ...

# %% [markdown]
# # Keyword as dictionary

# %%
user = json.load(open('data/user.json'))

user_keywords = user['user_keywords']
user_categories = user['user_categories']

# %% [markdown]
# # Keywords and Categories plus Recent

# %%
def recommend_news_based_on_keywords_and_preferences(keywords, vectors, data, user_preferences=None):
    # Initialize combined similarity column
    data['combined_similarity'] = 0.0
    
    # Iterate through each keyword and its score
    for keyword, score_info in keywords.items():
        score = score_info['score']
        # Calculate average word2vec representation for the keyword
        keyword_vec = get_average_word2vec(keyword.split(), vectors)
        
        # Calculate cosine similarity for each feature with the keyword
        data['title_similarity'] = data.apply(lambda row: cosine_similarity([row['title_vector']], [keyword_vec])[0][0], axis=1)
        data['short_desc_similarity'] = data.apply(lambda row: cosine_similarity([row['short_desc_vector']], [keyword_vec])[0][0], axis=1)
        data['desc_similarity'] = data.apply(lambda row: cosine_similarity([row['desc_vector']], [keyword_vec])[0][0], axis=1)

        # Combine similarities with weights
        title_weight = 0.7
        short_desc_weight = 0.2
        desc_weight = 0.1

        data['combined_similarity'] += (title_weight * data['title_similarity'] +
                                        short_desc_weight * data['short_desc_similarity'] +
                                        desc_weight * data['desc_similarity']) * score
    
    # Sort by combined similarity
    data = data.sort_values(by='combined_similarity', ascending=False)

    data = data.sort_values(by='date_created', ascending=False)

    
    # Prioritize articles based on user preferences for categories
    if user_preferences:
        category_weights = user_preferences
        category_max_score = max(category_weights.values(), key=lambda x: x['score'])['score']
        for category, weight_info in category_weights.items():
            weight = weight_info['score']
            data.loc[data['category'] == category, 'combined_similarity'] *= (weight / category_max_score)
    
    # Sort again by adjusted combined similarity
    data = data.sort_values(by='combined_similarity', ascending=False)
    
    return data

recommend_news_based_on_keywords_and_preferences(user_keywords, glove_model, data, user_categories)[:20]
# Out:
#                                                     url  \
# 1096  https://www.bloombergquint.com/businessweek/im...
# 1641  https://www.bloombergquint.com/onweb/who-shoul...
# 522   https://www.bloombergquint.com/onweb/sun-life-...
# 3368  https://www.bloombergquint.com/global-economic...
# 1366  https://www.bloombergquint.com/global-economic...
# 3413  https://www.bloombergquint.com/onweb/world-s-m...
# 375   https://www.bloombergquint.com/onweb/small-gro...
# 1851  https://www.bloombergquint.com/global-economic...
# 3929  https://www.bloombergquint.com/onweb/climate-c...
# 177   https://www.bloombergquint.com/global-economic...
# 231   https://www.bloombergquint.com/markets/five-th...
# 2122  https://www.bloombergquint.com/global-economic...
# 399   https://www.bloombergquint.com/onweb/return-to...
# 1455  https://www.bloombergquint.com/global-economic...
# 86    https://www.bloombergquint.com/markets/five-th...
# 2846  https://www.bloombergquint.com/quicktakes/why-...
# ...

# %% [markdown]
# # Basic functions

# %%
def preprocessing(text):
    text = _removeNonAscii(text)
    text = make_lower_case(text)
    text = remove_stop_words(text)
    text = remove_punctuation(text)
    text = remove_html(text)
    text = text.split()
    return text

def update_like_keywords(text, user_keywords, current_time, weight=0.1):
    text = preprocessing(text)
    
    for keyword in text:
        if keyword in user_keywords:
            user_keywords[keyword]['score'] += user_keywords[keyword]['score'] * weight
            user_keywords[keyword]['last_modified'] = current_time
            if user_keywords[keyword]['score'] > 5:
                user_keywords[keyword]['score'] = 5
        else:
            user_keywords[keyword] = {'score': 2.5, 'last_modified': current_time}
    return user_keywords

def update_like_categories(category, user_categories, current_time, weight=0.1):
    if category in user_categories:
        user_categories[category]['score'] += user_categories[category]['score'] * weight
        user_categories[category]['last_modified'] = current_time
        if user_categories[category]['score'] > 5:
            user_categories[category]['score'] = 5
    else:
        user_categories[category] = {'score': 2.5, 'last_modified': current_time}
    return user_categories


def update_dislike_keywords(text, user_keywords, current_time, weight=0.1):
    text = preprocessing(text)
    
    for keyword in text:
        if keyword in user_keywords:
            user_keywords[keyword]['score'] -= user_keywords[keyword]['score'] * weight
            user_keywords[keyword]['last_modified'] = current_time
            if user_keywords[keyword]['score'] < 0:
                user_keywords[keyword]['score'] = 0
        else:
            user_keywords[keyword] = {'score': 0.5, 'last_modified': current_time}
    return user_keywords

def update_dislike_categories(category, user_categories, current_time, weight=0.1):
    if category in user_categories:
        user_categories[category]['score'] -= user_categories[category]['score'] * weight
        user_categories[category]['last_modified'] = current_time
        if user_categories[category]['score'] < 0:
            user_categories[category]['score'] = 0
    else:
        user_categories[category] = {'score': 0.5, 'last_modified': current_time}
    return user_categories


def delete_overflow_keywords(user_keywords):
    if len(user_keywords) > 1000:
        sorted_keywords = sorted(user_keywords.items(), key=lambda x: x[1]['last_modified'], reverse=False)
        for keyword, data in sorted_keywords[:100]:
            del user_keywords[keyword]
    return user_keywords

def delete_overflow_categories(user_categories):
    if len(user_categories) > 1000:
        sorted_categories = sorted(user_categories.items(), key=lambda x: x[1]['last_modified'], reverse=False)
        for category, data in sorted_categories[:100]:
            del user_categories[category]
    return user_categories

# %% [markdown]
# # Viewing history

# %%
import json
from collections import OrderedDict
from datetime import datetime

user = json.load(open('data/user.json'))

def update_view_history(user_data, article_history):
    user_keywords = user_data['user_keywords']
    user_categories = user_data['user_categories']

    current_time = datetime.now().timestamp()

    for article in article_history:
        category = article['category']

        # Update keywords
        update_like_keywords(article['title'], user_keywords, current_time, weight=0.1)

        # Update categories
        update_like_categories(category, user_categories, current_time, weight=0.1)
            
    sorted_keywords = sorted(user_keywords.items(), key=lambda x: x[1]['last_modified'], reverse=True)
    sorted_categories = sorted(user_categories.items(), key=lambda x: x[1]['last_modified'], reverse=True)

    updated_keywords = OrderedDict()
    updated_categories = OrderedDict()

    for keyword, score in sorted_keywords:
        updated_keywords[keyword] = score

    for category, score in sorted_categories:
        updated_categories[category] = score

    updated_keywords = delete_overflow_keywords(updated_keywords)
    updated_categories = delete_overflow_categories(updated_categories)

    user_data['user_keywords'] = updated_keywords
    user_data['user_categories'] = updated_categories
    
    with open('data/user.json', 'w') as f:
        json.dump(user_data, f, indent=4)

update_view_history(user, user['user_history']['articles'])

# %% [markdown]
# # Feedback system

# %%
articles = [
        {
            "title": "The Benefits of Meditation: How It Can Improve Your Mental Well-being",
            "category": "Health"
        },
        {
            "title": "Exploring the Wonders of Deep Sea Creatures: A Dive into the Abyss",
            "category": "Nature"
        },
        {
            "title": "Unlocking Creativity: Techniques to Boost Your Innovative Thinking",
            "category": "Education"
        },
        {
            "title": "The Rise of Plant-Based Diets: Understanding the Vegan Lifestyle",
            "category": "Health"
        },
        {
            "title": "Exploring the Mysteries of the Universe: A Journey through Space",
            "category": "Science"
        },
        {
            "title": "The Art of Photography: Capturing Moments That Last a Lifetime",
            "category": "Art"
        },
        {
            "title": "The Power of Positive Thinking: Transforming Your Mindset for Success",
            "category": "Self-Help"
        },
        {
            "title": "Delving into Ancient History: Unraveling the Secrets of the Past",
            "category": "History"
        },
        {
            "title": "Understanding Climate Change: Impact, Causes, and Solutions",
            "category": "Environment"
        },
        {
            "title": "The Future of Renewable Energy: Innovations Shaping a Sustainable World",
            "category": "Science"
        }
    ]

# %%
articles1 = [
    {
        "title": "The Importance of Exercise: Enhancing Physical Health and Fitness",
        "category": "Health"
    },
    {
        "title": "Biodiversity Hotspots: Protecting Earth's Most Precious Ecosystems",
        "category": "Environment"
    },
    {
        "title": "Advancements in Artificial Intelligence: Shaping the Future of Technology",
        "category": "Science"
    },
    {
        "title": "Appreciating Classical Music: A Journey Through Timeless Compositions",
        "category": "Art"
    },
    {
        "title": "Leadership Skills: Key Traits and Strategies for Effective Leadership",
        "category": "Business"
    },
    {
        "title": "Exploring the Philosophy of Existentialism: Finding Meaning in a Chaotic World",
        "category": "Education"
    },
    {
        "title": "The Psychology of Decision Making: Understanding Human Choices and Behaviors",
        "category": "Science"
    },
    {
        "title": "Healthy Eating Habits: Tips for a Balanced Diet and Nutritional Wellness",
        "category": "Health"
    },
    {
        "title": "Artificial Intelligence in Healthcare: Revolutionizing Patient Care and Diagnosis",
        "category": "Science"
    },
    {
        "title": "The Evolution of Language: Tracing the Origins and Development of Communication",
        "category": "Science"
    }
]

# %%
def set_feedback(user_data, article, feedback):
    current_time = datetime.now().timestamp()

    # Update keywords
    if feedback.lower() == 'like':
        if article not in user_data['liked_articles']:
            user_data['user_keywords'] = update_like_keywords(article['title'], user_data['user_keywords'], current_time, weight=0.8)
    elif feedback.lower() == 'dislike':
        if article not in user_data['disliked_articles']:
            user_data['user_keywords'] = update_dislike_keywords(article['title'], user_data['user_keywords'], current_time, weight=0.8)

    # Update category
    if feedback.lower() == 'like':
        if article not in user_data['liked_articles']:
            user_data['user_categories'] = update_like_categories(article['category'], user_data['user_categories'], current_time, weight=0.8)
    elif feedback.lower() == 'dislike':
        if article not in user_data['disliked_articles']:
            user_data['user_categories'] = update_dislike_categories(article['category'], user_data['user_categories'], current_time, weight=0.8)

    # Check if liked_articles/disliked_articles keys exist
    if 'liked_articles' not in user_data:
        user_data['liked_articles'] = []
    if 'disliked_articles' not in user_data:
        user_data['disliked_articles'] = []

    # Memorize the liked/disliked article
    if feedback.lower() == 'like' and article not in user_data['liked_articles']:
        user_data['liked_articles'].append(article)
    elif feedback.lower() == 'dislike' and article not in user_data['disliked_articles']:
        user_data['disliked_articles'].append(article)
    else:
        print("Article already present in either like or dislike")

    # Sort user_keywords and user_categories by last modified time
    user_data['user_keywords'] = OrderedDict(sorted(user_data['user_keywords'].items(), key=lambda x: x[1]['last_modified'], reverse=True))
    user_data['user_categories'] = OrderedDict(sorted(user_data['user_categories'].items(), key=lambda x: x[1]['last_modified'], reverse=True))

    with open('data/user_demo.json', 'w') as f:
        json.dump(user_data, f, indent=4)
    

""" user = json.load(open('data/user.json'))
article = articles1[np.random.randint(0, len(articles1))]
print(article)
set_feedback(user, article, 'like') """
# Out:
# " user = json.load(open('data/user.json'))\narticle = articles1[np.random.randint(0, len(articles1))]\nprint(article)\nset_feedback(user, article, 'like') "

# %% [markdown]
# # DEMO

# %%
user = json.load(open('data/user_demo.json'))

user_keywords = user['user_keywords']
user_categories = user['user_categories']

print(user_categories)
print(user_keywords)


recommend_news_based_on_keywords_and_preferences(user_keywords, glove_model, data, user_categories)[:20]
# Out:
# {'Education': {'score': 2.5920000000000005, 'last_modified': 1712050144.041242}, 'Art': {'score': 1.4400000000000002, 'last_modified': 1712050058.081056}, 'Environment': {'score': 1.4400000000000002, 'last_modified': 1712050036.192425}, 'Business': {'score': 0.0, 'last_modified': 1712049945.281864}, 'Life': {'score': 0.1, 'last_modified': 1712048431.113002}, 'Technology': {'score': 0, 'last_modified': 1712048431.113002}, 'Nature': {'score': 0.8, 'last_modified': 1711820408.861159}, 'Self-Help': {'score': 0.8, 'last_modified': 1711820402.950997}, 'History': {'score': 0.8, 'last_modified': 1711820401.579802}, 'Opinion/Gadfly': {'score': 0, 'last_modified': 1648700000}}
# ...

# %%
user = json.load(open('data/user_demo.json'))

article_like = {
        "title": "Advancements in Artificial Intelligence: Shaping the Future of Technology",
        "category": "Science"
    }

set_feedback(user, article_like, 'like')

# %%
user = json.load(open('data/user_demo.json'))

article_dislike = {
        "title": "Biodiversity Hotspots: Protecting Earth's Most Precious Ecosystems",
        "category": "Environment"
    }

set_feedback(user, article_dislike, 'dislike')

# %%
user = json.load(open('data/user_demo.json'))

user_keywords = user['user_keywords']
user_categories = user['user_categories']


recommend_news_based_on_keywords_and_preferences(user_keywords, glove_model, data, user_categories)[:20]
# Out:
#                                                     url  \
# 1096  https://www.bloombergquint.com/businessweek/im...
# 97    https://www.bloombergquint.com/markets/eurofin...
# 1641  https://www.bloombergquint.com/onweb/who-shoul...
# 3370  https://www.bloombergquint.com/onweb/eu-eyes-r...
# 1292  https://www.bloombergquint.com/research-report...
# 2846  https://www.bloombergquint.com/quicktakes/why-...
# 375   https://www.bloombergquint.com/onweb/small-gro...
# 3832  https://www.bloombergquint.com/china/china-is-...
# 3413  https://www.bloombergquint.com/onweb/world-s-m...
# 1455  https://www.bloombergquint.com/global-economic...
# 3633  https://www.bloombergquint.com/global-economic...
# 3357  https://www.bloombergquint.com/opinion/michael...
# 2234  https://www.bloombergquint.com/research-report...
# 1809  https://www.bloombergquint.com/politics/powers...
# 2685  https://www.bloombergquint.com/research-report...
# 410   https://www.bloombergquint.com/onweb/climate-c...
# ...
